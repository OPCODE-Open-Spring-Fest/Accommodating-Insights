# %% [markdown]
# # Problem Statement
#
# Guests and hosts have used hospitality industries to expand on travelling possibilities
# and present a more unique, personalised way of experiencing the world.
# Data analysis on millions of listings provided through these industries are crucial for the company.
# These millions of listings generate a lot of data , data that can be analysed and
# used for security, business decisions, understanding of customers and provider (hosts) behaviour
# and performance on the platform, guiding marketing initiatives, implementation of
# innovative additional services and much more.
#
# Explore and analyze the data to discover key understandings (not limited to these) such as :
# * What can we learn about different hosts and areas?
#
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %% [markdown]
# * This data file includes all needed information to find out more about hosts, geographical availability, necessary metrics to make predictions and draw conclusions.
#
# * The data contains 48895 rows and 16 columns.
#
# * The data contains information about the id, host name, host_id, host_name, neighbourhood_group, neighbouhood, latitude, longitude, room type, price, minimum number of nights, number of reviews, last review, reviews per month, calculated host listings count, and availability during the year.
#
#
# 1. `id`: Unique ID of the industry listing.
#
# 2. `name`: Name of the listed property.
# 3. `host_id`: Unique ID of the host.
# 4. `host_name`: Name of the host.
# 5. `neighbourhood_group`: General region of the location (neighborhood), e.g., Brooklyn, Manhattan, Queens, Staten Island, and Bronx.
# 6. `neighbourhood`: Specific neighborhood where the property is located.
# 7. `latitude`: Latitude coordinate of the property.
# 8. `longitude`: Longitude coordinate of the property.
# 9. `room_type`: Type of room (e.g., Private room, Shared room, Entire home/apt).
# 10. `price`: Price per night (in USD).
# 11. `minimum_nights`: Minimum number of nights guests are required to stay.
# 12. `number_of_reviews`: Number of reviews the listing has received.
# 13. `last_review`: Date of the last review.
# 14. `reviews_per_month`: Average number of reviews per month.
# 15. `calculated_host_listings_count`: Total number of properties listed by the host.
# 16. `availability_365`: Number of days the property is available in a year.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV


from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Loading the data `

# %%
df = pd.read_csv("hotel.csv")

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
len(df) , len(df.columns)

## as we can see we have 16 features and 48895 rows
# Out:
# (48895, 16)

# %% [markdown]
# ### There are also features which are of no use

# %%
# We dropped the variables that are not useful from the dataset.

drop_list = ['id', 'host_id', 'host_name', 'last_review']

# %%
df.drop(drop_list, axis = 1, inplace=True)

# %%
df.head()
# Out:
#                                                name neighbourhood_group  \
# 0                Clean & quiet apt home by the park            Brooklyn
# 1                             Skylit Midtown Castle           Manhattan
# 2               THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                   Cozy Entire Floor of Brownstone            Brooklyn
# 4  Entire Apt: Spacious Studio/Loft by central park           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Kensington  40.64749  -73.97237     Private room    149               1
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
# 3  Clinton Hill  40.68514  -73.95976  Entire home/apt     89               1
# 4   East Harlem  40.79851  -73.94399  Entire home/apt     80              10
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
# 2                  0                NaN                               1
# 3                270               4.64                               1
# 4                  9               0.10                               1
#
#    availability_365
# 0               365
# 1               355
# 2               365
# 3               194
# 4                 0

# %%
len(df.columns)
# Out:
# 12

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.shape
# Out:
# (48895, 12)

# %%
df.dtypes
# Out:
# name                               object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.tail()
# Out:
#                                                     name neighbourhood_group  \
# 48890    Charming one bedroom - newly renovated rowhouse            Brooklyn
# 48891      Affordable room in Bushwick/East Williamsburg            Brooklyn
# 48892            Sunny Studio at Historical Neighborhood           Manhattan
# 48893               43rd St. Time Square-cozy single bed           Manhattan
# 48894  Trendy duplex in the very heart of Hell's Kitchen           Manhattan
#
#             neighbourhood  latitude  longitude        room_type  price  \
# 48890  Bedford-Stuyvesant  40.67853  -73.94995     Private room     70
# 48891            Bushwick  40.70184  -73.93317     Private room     40
# 48892              Harlem  40.81475  -73.94867  Entire home/apt    115
# 48893      Hell's Kitchen  40.75751  -73.99112      Shared room     55
# 48894      Hell's Kitchen  40.76404  -73.98933     Private room     90
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 48890               2                  0                NaN
# 48891               4                  0                NaN
# 48892              10                  0                NaN
# 48893               1                  0                NaN
# 48894               7                  0                NaN
#
#        calculated_host_listings_count  availability_365
# 48890                               2                 9
# 48891                               2                36
# 48892                               1                27
# 48893                               6                 2
# 48894                               1                23

# %%
df.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48895.000000  48895.000000  48895.000000    48895.000000
# mean      40.728949    -73.952170    152.720687        7.029962
# std        0.054530      0.046157    240.154170       20.510550
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690100    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763115    -73.936275    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       38843.000000                    48895.000000
# mean           23.274466           1.373221                        7.143982
# std            44.550582           1.680442                       32.952519
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.190000                        1.000000
# 50%             5.000000           0.720000                        1.000000
# 75%            24.000000           2.020000                        2.000000
# max           629.000000          58.500000                      327.000000
#
#        availability_365
# count      48895.000000
# mean         112.781327
# std          131.622289
# min            0.000000
# 25%            0.000000
# 50%           45.000000
# 75%          227.000000
# max          365.000000

# %%
df.isnull().sum()
# Out:
# name                                 16
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ## Price by Room Type

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='room_type', y='price', data = df)

plt.xlabel('Room Type', size=13)
plt.ylabel('Price', size = 13)
plt.title('Room Type v/s Price', size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Room Type v/s Price')

# %% [markdown]
# `Observation`: Shared room is always lower than 2,000 dollars. On the other hand,
#     `Private Room ` and `Entire home/apartment` is normally higher than Shared room.

# %% [markdown]
# ## Price by Neighbourhood Group

# %% [markdown]
# mainly we have 5 neighbouring cities : Brooklyn, Manhattan, Queens, Staten Island and
#     Bronx

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='neighbourhood_group', y= 'price', data=df,
               hue='neighbourhood_group', palette='Dark2')

plt.xlabel('Neighbourhood Group', size=13)
plt.ylabel('Price', size=13)
plt.title('Neighbourhood Group v/s Price', size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group v/s Price')

# %% [markdown]
# `Observation`: In average, the higher price of room is in `Manhattan` and `Brooklyn`. On the other hands, there are a lot of lower price rooms in `Queens`, `Staten Island`, and `Bronx`.

# %% [markdown]
# ## Price by number of reviews

# %%
# plot a graph for price v/s Number of Reviews 
# And provide the observation made

# %%
price_query = df['price'].describe()
price_query
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
from scipy.stats import norm

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['price'], fit=norm)
plt.title("Price Distribution Plot",size=15, weight='bold');
plt.show()
# Out:
# C:\Users\devco\AppData\Local\Temp\ipykernel_22212\3154228031.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], fit=norm)

# %%
# Take the log transformation of the price and add it as the 'price_log' column to the dataframe

# %%
# Plot a normal distribution curve for the 'price_log'

# %%
## Dropping string values
dff = df.copy()

# %%
dff.head()
# Out:
#                                                name neighbourhood_group  \
# 0                Clean & quiet apt home by the park            Brooklyn
# 1                             Skylit Midtown Castle           Manhattan
# 2               THE VILLAGE OF HARLEM....NEW YORK !           Manhattan
# 3                   Cozy Entire Floor of Brownstone            Brooklyn
# 4  Entire Apt: Spacious Studio/Loft by central park           Manhattan
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Kensington  40.64749  -73.97237     Private room    149               1
# 1       Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 2        Harlem  40.80902  -73.94190     Private room    150               3
# 3  Clinton Hill  40.68514  -73.95976  Entire home/apt     89               1
# 4   East Harlem  40.79851  -73.94399  Entire home/apt     80              10
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
# 2                  0                NaN                               1
# 3                270               4.64                               1
# 4                  9               0.10                               1
#
#    availability_365  price_log
# 0               365   5.010635
# 1               355   5.420535
# 2               365   5.017280
# 3               194   4.499810
# 4                 0   4.394449

# %%
dff.drop(['name'], axis = 1, inplace = True)

# %% [markdown]
# ### Data Pre-Processing

# %%
df.isnull().sum()
# Out:
# name                                 16
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# price_log                             0
# dtype: int64

# %%
dff.isna().sum()
# Out:
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# price_log                             0
# dtype: int64

# %% [markdown]
# #### Replacing the missing data (NAN or null values)

# %%
## you can use .fillna() to replace the null values

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  object
#  1   neighbourhood                   48895 non-null  object
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  object
#  5   price                           48895 non-null  int64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   reviews_per_month               48895 non-null  float64
#  9   calculated_host_listings_count  48895 non-null  int64
#  10  availability_365                48895 non-null  int64
#  11  price_log                       48895 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# #### Observations:
#
# 3 features ('neighbourhood_group', neighbourhood', and 'room_type') are considered as object types, not nominal.
#
#
#
#
#
# Machine learning algorithms prefer in a numerical format over string types

# %%
original_categories = dff['neighbourhood_group'].astype("category").cat.categories

# Print the mapping between original values and codes
for original_value, code in zip(original_categories, range(len(original_categories))):
    print(f"Original Value: {original_value} | Code: {code}")
# Out:
# Original Value: Bronx | Code: 0
# Original Value: Brooklyn | Code: 1
# Original Value: Manhattan | Code: 2
# Original Value: Queens | Code: 3
# Original Value: Staten Island | Code: 4

# %%
original_categories = dff['neighbourhood'].astype("category").cat.categories

# Print the mapping between original values and codes
for original_value, code in zip(original_categories, range(len(original_categories))):
    print(f"Original Value: {original_value} | Code: {code}")
# Out:
# Original Value: Allerton | Code: 0
# Original Value: Arden Heights | Code: 1
# Original Value: Arrochar | Code: 2
# Original Value: Arverne | Code: 3
# Original Value: Astoria | Code: 4
# Original Value: Bath Beach | Code: 5
# Original Value: Battery Park City | Code: 6
# Original Value: Bay Ridge | Code: 7
# Original Value: Bay Terrace | Code: 8
# Original Value: Bay Terrace, Staten Island | Code: 9
# Original Value: Baychester | Code: 10
# Original Value: Bayside | Code: 11
# Original Value: Bayswater | Code: 12
# Original Value: Bedford-Stuyvesant | Code: 13
# Original Value: Belle Harbor | Code: 14
# Original Value: Bellerose | Code: 15
# Original Value: Belmont | Code: 16
# Original Value: Bensonhurst | Code: 17
# Original Value: Bergen Beach | Code: 18
# Original Value: Boerum Hill | Code: 19
# Original Value: Borough Park | Code: 20
# Original Value: Breezy Point | Code: 21
# Original Value: Briarwood | Code: 22
# Original Value: Brighton Beach | Code: 23
# Original Value: Bronxdale | Code: 24
# Original Value: Brooklyn Heights | Code: 25
# Original Value: Brownsville | Code: 26
# Original Value: Bull's Head | Code: 27
# Original Value: Bushwick | Code: 28
# Original Value: Cambria Heights | Code: 29
# Original Value: Canarsie | Code: 30
# Original Value: Carroll Gardens | Code: 31
# Original Value: Castle Hill | Code: 32
# Original Value: Castleton Corners | Code: 33
# Original Value: Chelsea | Code: 34
# Original Value: Chinatown | Code: 35
# Original Value: City Island | Code: 36
# Original Value: Civic Center | Code: 37
# Original Value: Claremont Village | Code: 38
# Original Value: Clason Point | Code: 39
# Original Value: Clifton | Code: 40
# Original Value: Clinton Hill | Code: 41
# Original Value: Co-op City | Code: 42
# Original Value: Cobble Hill | Code: 43
# Original Value: College Point | Code: 44
# Original Value: Columbia St | Code: 45
# Original Value: Concord | Code: 46
# Original Value: Concourse | Code: 47
# Original Value: Concourse Village | Code: 48
# Original Value: Coney Island | Code: 49
# Original Value: Corona | Code: 50
# Original Value: Crown Heights | Code: 51
# Original Value: Cypress Hills | Code: 52
# Original Value: DUMBO | Code: 53
# Original Value: Ditmars Steinway | Code: 54
# Original Value: Dongan Hills | Code: 55
# Original Value: Douglaston | Code: 56
# Original Value: Downtown Brooklyn | Code: 57
# Original Value: Dyker Heights | Code: 58
# Original Value: East Elmhurst | Code: 59
# Original Value: East Flatbush | Code: 60
# Original Value: East Harlem | Code: 61
# Original Value: East Morrisania | Code: 62
# Original Value: East New York | Code: 63
# Original Value: East Village | Code: 64
# Original Value: Eastchester | Code: 65
# Original Value: Edenwald | Code: 66
# Original Value: Edgemere | Code: 67
# Original Value: Elmhurst | Code: 68
# Original Value: Eltingville | Code: 69
# Original Value: Emerson Hill | Code: 70
# Original Value: Far Rockaway | Code: 71
# Original Value: Fieldston | Code: 72
# Original Value: Financial District | Code: 73
# Original Value: Flatbush | Code: 74
# Original Value: Flatiron District | Code: 75
# Original Value: Flatlands | Code: 76
# Original Value: Flushing | Code: 77
# Original Value: Fordham | Code: 78
# Original Value: Forest Hills | Code: 79
# Original Value: Fort Greene | Code: 80
# Original Value: Fort Hamilton | Code: 81
# Original Value: Fort Wadsworth | Code: 82
# Original Value: Fresh Meadows | Code: 83
# Original Value: Glendale | Code: 84
# Original Value: Gowanus | Code: 85
# Original Value: Gramercy | Code: 86
# Original Value: Graniteville | Code: 87
# Original Value: Grant City | Code: 88
# Original Value: Gravesend | Code: 89
# Original Value: Great Kills | Code: 90
# Original Value: Greenpoint | Code: 91
# Original Value: Greenwich Village | Code: 92
# Original Value: Grymes Hill | Code: 93
# Original Value: Harlem | Code: 94
# Original Value: Hell's Kitchen | Code: 95
# Original Value: Highbridge | Code: 96
# Original Value: Hollis | Code: 97
# Original Value: Holliswood | Code: 98
# Original Value: Howard Beach | Code: 99
# Original Value: Howland Hook | Code: 100
# Original Value: Huguenot | Code: 101
# Original Value: Hunts Point | Code: 102
# Original Value: Inwood | Code: 103
# Original Value: Jackson Heights | Code: 104
# Original Value: Jamaica | Code: 105
# Original Value: Jamaica Estates | Code: 106
# Original Value: Jamaica Hills | Code: 107
# Original Value: Kensington | Code: 108
# Original Value: Kew Gardens | Code: 109
# Original Value: Kew Gardens Hills | Code: 110
# Original Value: Kingsbridge | Code: 111
# Original Value: Kips Bay | Code: 112
# Original Value: Laurelton | Code: 113
# Original Value: Lighthouse Hill | Code: 114
# Original Value: Little Italy | Code: 115
# Original Value: Little Neck | Code: 116
# Original Value: Long Island City | Code: 117
# Original Value: Longwood | Code: 118
# Original Value: Lower East Side | Code: 119
# Original Value: Manhattan Beach | Code: 120
# Original Value: Marble Hill | Code: 121
# Original Value: Mariners Harbor | Code: 122
# Original Value: Maspeth | Code: 123
# Original Value: Melrose | Code: 124
# Original Value: Middle Village | Code: 125
# Original Value: Midland Beach | Code: 126
# Original Value: Midtown | Code: 127
# Original Value: Midwood | Code: 128
# Original Value: Mill Basin | Code: 129
# Original Value: Morningside Heights | Code: 130
# Original Value: Morris Heights | Code: 131
# Original Value: Morris Park | Code: 132
# Original Value: Morrisania | Code: 133
# Original Value: Mott Haven | Code: 134
# Original Value: Mount Eden | Code: 135
# Original Value: Mount Hope | Code: 136
# Original Value: Murray Hill | Code: 137
# Original Value: Navy Yard | Code: 138
# Original Value: Neponsit | Code: 139
# Original Value: New Brighton | Code: 140
# Original Value: New Dorp | Code: 141
# Original Value: New Dorp Beach | Code: 142
# Original Value: New Springville | Code: 143
# Original Value: NoHo | Code: 144
# Original Value: Nolita | Code: 145
# Original Value: North Riverdale | Code: 146
# Original Value: Norwood | Code: 147
# Original Value: Oakwood | Code: 148
# Original Value: Olinville | Code: 149
# Original Value: Ozone Park | Code: 150
# Original Value: Park Slope | Code: 151
# Original Value: Parkchester | Code: 152
# Original Value: Pelham Bay | Code: 153
# Original Value: Pelham Gardens | Code: 154
# Original Value: Port Morris | Code: 155
# Original Value: Port Richmond | Code: 156
# Original Value: Prince's Bay | Code: 157
# Original Value: Prospect Heights | Code: 158
# Original Value: Prospect-Lefferts Gardens | Code: 159
# Original Value: Queens Village | Code: 160
# Original Value: Randall Manor | Code: 161
# Original Value: Red Hook | Code: 162
# Original Value: Rego Park | Code: 163
# Original Value: Richmond Hill | Code: 164
# Original Value: Richmondtown | Code: 165
# Original Value: Ridgewood | Code: 166
# Original Value: Riverdale | Code: 167
# Original Value: Rockaway Beach | Code: 168
# Original Value: Roosevelt Island | Code: 169
# Original Value: Rosebank | Code: 170
# Original Value: Rosedale | Code: 171
# Original Value: Rossville | Code: 172
# Original Value: Schuylerville | Code: 173
# Original Value: Sea Gate | Code: 174
# Original Value: Sheepshead Bay | Code: 175
# Original Value: Shore Acres | Code: 176
# Original Value: Silver Lake | Code: 177
# Original Value: SoHo | Code: 178
# Original Value: Soundview | Code: 179
# Original Value: South Beach | Code: 180
# Original Value: South Ozone Park | Code: 181
# Original Value: South Slope | Code: 182
# Original Value: Springfield Gardens | Code: 183
# Original Value: Spuyten Duyvil | Code: 184
# Original Value: St. Albans | Code: 185
# Original Value: St. George | Code: 186
# Original Value: Stapleton | Code: 187
# Original Value: Stuyvesant Town | Code: 188
# Original Value: Sunnyside | Code: 189
# Original Value: Sunset Park | Code: 190
# Original Value: Theater District | Code: 191
# Original Value: Throgs Neck | Code: 192
# Original Value: Todt Hill | Code: 193
# Original Value: Tompkinsville | Code: 194
# Original Value: Tottenville | Code: 195
# Original Value: Tremont | Code: 196
# Original Value: Tribeca | Code: 197
# Original Value: Two Bridges | Code: 198
# Original Value: Unionport | Code: 199
# Original Value: University Heights | Code: 200
# Original Value: Upper East Side | Code: 201
# Original Value: Upper West Side | Code: 202
# Original Value: Van Nest | Code: 203
# Original Value: Vinegar Hill | Code: 204
# Original Value: Wakefield | Code: 205
# Original Value: Washington Heights | Code: 206
# Original Value: West Brighton | Code: 207
# Original Value: West Farms | Code: 208
# Original Value: West Village | Code: 209
# Original Value: Westchester Square | Code: 210
# Original Value: Westerleigh | Code: 211
# Original Value: Whitestone | Code: 212
# Original Value: Williamsbridge | Code: 213
# Original Value: Williamsburg | Code: 214
# Original Value: Willowbrook | Code: 215
# Original Value: Windsor Terrace | Code: 216
# Original Value: Woodhaven | Code: 217
# Original Value: Woodlawn | Code: 218
# Original Value: Woodrow | Code: 219
# Original Value: Woodside | Code: 220

# %%
original_categories = dff['room_type'].astype("category").cat.categories

# Print the mapping between original values and codes
for original_value, code in zip(original_categories, range(len(original_categories))):
    print(f"Original Value: {original_value} | Code: {code}")

# %%
# Change the non-numerical value to numerical value
# hint u can use cat.code

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  int8
#  1   neighbourhood                   48895 non-null  int16
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  int8
#  5   price                           48895 non-null  int64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   reviews_per_month               48895 non-null  float64
#  9   calculated_host_listings_count  48895 non-null  int64
#  10  availability_365                48895 non-null  int64
#  11  price_log                       48895 non-null  float64
# dtypes: float64(4), int16(1), int64(5), int8(2)
# memory usage: 3.5 MB

# %% [markdown]
# #### So we have successfully converted all the object/string type to numerical type

# %% [markdown]
# ## Detecting Numeric and Categorical Variables

# %%
def col_names(dataframe, cat_th=10, car_th=20):
    
    cat_cols = [col for col in dataframe.columns if dataframe[col].dtypes == "O"] 

    num_but_cat = [col for col in dataframe.columns if dataframe[col].nunique() < cat_th and
                   dataframe[col].dtypes != "O"]

    cat_but_car = [col for col in dataframe.columns if dataframe[col].nunique() > car_th and
                   dataframe[col].dtypes == "O"]

    cat_cols = cat_cols + num_but_cat

    cat_cols = [col for col in cat_cols if col not in cat_but_car] 

    num_cols = [col for col in dataframe.columns if dataframe[col].dtypes != "O"] 

    num_cols = [col for col in num_cols if col not in num_but_cat] 
    
    print(f"Observations: {dataframe.shape[0]}") 
    print(f"Variables: {dataframe.shape[1]}") 
    print(f'cat_cols: {len(cat_cols)}') 
    print(f'num_cols: {len(num_cols)}') 
    print(f'cat_but_car: {len(cat_but_car)}') 
    print(f'num_but_cat: {len(num_but_cat)}') 


    return cat_cols, num_cols, cat_but_car, num_but_cat

# %%
cat_cols, num_cols, cat_but_car, num_but_cat = col_names(dff)
# Out:
# Observations: 48895
# Variables: 12
# cat_cols: 2
# num_cols: 10
# cat_but_car: 0
# num_but_cat: 2

# %%
cat_cols
# Out:
# ['neighbourhood_group', 'room_type']

# %%
num_cols
# Out:
# ['neighbourhood',
#  'latitude',
#  'longitude',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'price_log']

# %%
cat_but_car
# Out:
# []

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  int8
#  1   neighbourhood                   48895 non-null  int16
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  int8
#  5   price                           48895 non-null  int64
#  6   minimum_nights                  48895 non-null  int64
#  7   number_of_reviews               48895 non-null  int64
#  8   reviews_per_month               48895 non-null  float64
#  9   calculated_host_listings_count  48895 non-null  int64
#  10  availability_365                48895 non-null  int64
#  11  price_log                       48895 non-null  float64
# dtypes: float64(4), int16(1), int64(5), int8(2)
# memory usage: 3.5 MB

# %% [markdown]
# ## Correlation Analysis

# %%
## Give the correlation between the features and tell which features 
# are correlated

# %% [markdown]
# ## Visualizing Location Data Based on Neighbourhood Group and Room Type

# %%
title = 'Neighbourbood Group Location'
plt.figure(figsize=(10,6))
sns.scatterplot(x='longitude', y='latitude', hue='neighbourhood_group', data= dff).set_title(title)

plt.ioff()

title = 'Room type location per Neighbourhood Group'

plt.figure(figsize=(10,6))
sns.scatterplot(x='longitude', y='latitude', hue='room_type', data=dff).set_title(title)
plt.ioff()

# %% [markdown]
# ## Geographical Distribution of Prices

# %% [markdown]
# ## Geographical Distribution of Availability

# %%
# show using scatter plot the geographical distribution of Availability

# %%
labels = dff.neighbourhood_group.value_counts().index
colors = ['green','yellow','orange','pink','red']
explode = [0,0,0,0,0]
sizes = dff.neighbourhood_group.value_counts().values

plt.figure(0,figsize = (7,7))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('According to Neighbourhood Group',color = 'blue',fontsize = 15)
plt.show()

# %% [markdown]
# ## Price Distribution by Room Type in Neighbourhood Groups

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = "neighbourhood_group", y = "price", hue = "room_type", data = dff)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Comaparision of Minimum Stay Nights By NeighbourHood Group

# %%
plt.figure(figsize=(12,6))

result = dff.groupby(["neighbourhood_group"])['minimum_nights'].aggregate(np.median).reset_index().sort_values('minimum_nights')

sns.barplot(x='neighbourhood_group', y="minimum_nights", data=dff, order=result['neighbourhood_group'])

plt.show()

# %% [markdown]
# ## Outliers Analysis

# %% [markdown]
# ### Analysis using Boxplot

# %%
plt.figure(figsize=(6,6))
sns.boxplot(y=np.log1p(dff['price']))
plt.title("Distribution of Prices")
plt.show()

# %%
# boxplot for 'room_type' and price

# %%
# Boxplot for 'neighbourhood_group' and price

# %%
dff.head()
# Out:
#    neighbourhood_group  neighbourhood  latitude  longitude  room_type  price  \
# 0                    1            108  40.64749  -73.97237          1    149
# 1                    2            127  40.75362  -73.98377          0    225
# 2                    2             94  40.80902  -73.94190          1    150
# 3                    1             41  40.68514  -73.95976          0     89
# 4                    2             61  40.79851  -73.94399          0     80
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9           0.210000
# 1               1                 45           0.380000
# 2               3                  0           1.373221
# 3               1                270           4.640000
# 4              10                  9           0.100000
#
#    calculated_host_listings_count  availability_365  price_log
# 0                               6               365   5.010635
# 1                               2               355   5.420535
# 2                               1               365   5.017280
# 3                               1               194   4.499810
# 4                               1                 0   4.394449

# %%
def outlier_thresholds(dataframe , col_name , q1= 0.05, q3= 0.95):
    quartile1 = dataframe[col_name].quantile(q1)
    quartile3 = dataframe[col_name].quantile(q3)
    
    interquantile_range = quartile3 - quartile1
    up_limit = quartile3 + 1.5*interquantile_range
    low_limit = quartile1 - 1.5*interquantile_range
    
    return low_limit, up_limit

# %%
# Make a function to check outliers

# %%
for col in num_cols:
    print(col, check_outlier(dff, col))
# Out:
# neighbourhood False
# latitude False
# longitude True
# price True
# minimum_nights True
# number_of_reviews True
# reviews_per_month True
# calculated_host_listings_count True
# availability_365 False
# price_log True

# %%
df2 = dff.copy()

# %%
## Fixing the outliers 

# Replace the outliers 
# Hint: You can take all the outliers within the quantile range

# %%
for col in num_cols:
    if check_outlier(dff, col):
        replace_with_thresholds(dff, col)

# %%
for col in num_cols:
    print(col, check_outlier(dff, col))
# Out:
# neighbourhood False
# latitude False
# longitude False
# price False
# minimum_nights False
# number_of_reviews False
# reviews_per_month False
# calculated_host_listings_count False
# availability_365 False
# price_log False

# %%
# This feature represents the total cost of the house for the minimum number of nights. It takes the total of the price for minimum nights.
dff['NEW_total_cost'] = dff['price'] * dff['minimum_nights']

# This feature can be used to estimate for how long a house has been listed. This duration is calculated by dividing the total number of reviews that the house has received by the number of reviews per month.
dff['NEW_estimated_listed_months'] = dff['number_of_reviews'] / dff['reviews_per_month']

# This feature gives the ratio of how long a house is available throughout the year.
dff['NEW_availability_ratio'] = dff['availability_365'] / 365

# This feature gives the daily average reviews a host receives. It divides the reviews per month by the number of days in a month.
dff['NEW_daily_average_reviews'] = dff['reviews_per_month'] / 30

# This feature estimates how much a host can earn in a year. It multiplies the price of a house with how many days it is available in a year.
dff['NEW_annual_income'] = dff['price'] * dff['availability_365']

# This feature estimates the average duration a customer stays. It divides the total number of reviews by the reviews per month.
dff['NEW_average_stay_duration'] = dff['number_of_reviews'] / dff['reviews_per_month']

# This feature gives the occupancy rate of a house throughout the year. It subtracts from 365 the number of days a house is available in a year.
dff['NEW_house_occupancy_rate'] = 365 - dff['availability_365']

# This feature determines the minimum amount a house can get for a booking. It multiplies the price of a house with the minimum nights.
dff['NEW_minimum_income'] = dff['price'] * dff['minimum_nights']

# %%
dff.head()
# Out:
#    neighbourhood_group  neighbourhood  latitude  longitude  room_type  price  \
# 0                    1            108  40.64749  -73.97237          1  149.0
# 1                    2            127  40.75362  -73.98377          0  225.0
# 2                    2             94  40.80902  -73.94190          1  150.0
# 3                    1             41  40.68514  -73.95976          0   89.0
# 4                    2             61  40.79851  -73.94399          0   80.0
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0             1.0                  9           0.210000
# 1             1.0                 45           0.380000
# 2             3.0                  0           1.373221
# 3             1.0                270           4.640000
# 4            10.0                  9           0.100000
#
#    calculated_host_listings_count  availability_365  price_log  \
# 0                               6               365   5.010635
# 1                               2               355   5.420535
# 2                               1               365   5.017280
# 3                               1               194   4.499810
# 4                               1                 0   4.394449
#
#    NEW_total_cost  NEW_estimated_listed_months  NEW_availability_ratio  \
# 0           149.0                    42.857143                1.000000
# 1           225.0                   118.421053                0.972603
# 2           450.0                     0.000000                1.000000
# 3            89.0                    58.189655                0.531507
# 4           800.0                    90.000000                0.000000
#
#    NEW_daily_average_reviews  NEW_annual_income  NEW_average_stay_duration  \
# 0                   0.007000            54385.0                  42.857143
# 1                   0.012667            79875.0                 118.421053
# 2                   0.045774            54750.0                   0.000000
# 3                   0.154667            17266.0                  58.189655
# 4                   0.003333                0.0                  90.000000
#
#    NEW_house_occupancy_rate  NEW_minimum_income
# 0                         0               149.0
# 1                        10               225.0
# 2                         0               450.0
# 3                       171                89.0
# 4                       365               800.0

# %% [markdown]
# ## Encoding

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             48895 non-null  int8
#  1   neighbourhood                   48895 non-null  int16
#  2   latitude                        48895 non-null  float64
#  3   longitude                       48895 non-null  float64
#  4   room_type                       48895 non-null  int8
#  5   price                           48895 non-null  float64
#  6   minimum_nights                  48895 non-null  float64
#  7   number_of_reviews               48895 non-null  int64
#  8   reviews_per_month               48895 non-null  float64
#  9   calculated_host_listings_count  48895 non-null  int64
#  10  availability_365                48895 non-null  int64
#  11  price_log                       48895 non-null  float64
#  12  NEW_total_cost                  48895 non-null  float64
#  13  NEW_estimated_listed_months     48895 non-null  float64
#  14  NEW_availability_ratio          48895 non-null  float64
#  15  NEW_daily_average_reviews       48895 non-null  float64
#  16  NEW_annual_income               48895 non-null  float64
#  17  NEW_average_stay_duration       48895 non-null  float64
#  18  NEW_house_occupancy_rate        48895 non-null  int64
#  19  NEW_minimum_income              48895 non-null  float64
# dtypes: float64(13), int16(1), int64(4), int8(2)
# memory usage: 6.5 MB

# %%
cat_cols, num_cols, cat_but_car,  num_but_cat = col_names(dff)
# Out:
# Observations: 48895
# Variables: 20
# cat_cols: 2
# num_cols: 18
# cat_but_car: 0
# num_but_cat: 2

# %%
num_cols
# Out:
# ['neighbourhood',
#  'latitude',
#  'longitude',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'price_log',
#  'NEW_total_cost',
#  'NEW_estimated_listed_months',
#  'NEW_availability_ratio',
#  'NEW_daily_average_reviews',
#  'NEW_annual_income',
#  'NEW_average_stay_duration',
#  'NEW_house_occupancy_rate',
#  'NEW_minimum_income']

# %%
cat_but_car
# Out:
# []

# %%
cat_cols
# Out:
# ['neighbourhood_group', 'room_type']

# %%
def one_hot_encoder(dataframe, categorical_cols, drop_first=False):
    dataframe = pd.get_dummies(dataframe, columns=categorical_cols, drop_first=drop_first)
    return dataframe

# %%
dff = one_hot_encoder(dff, cat_cols, drop_first=True)

# %%
dff.head()
# Out:
#    neighbourhood  latitude  longitude  price  minimum_nights  \
# 0            108  40.64749  -73.97237  149.0             1.0
# 1            127  40.75362  -73.98377  225.0             1.0
# 2             94  40.80902  -73.94190  150.0             3.0
# 3             41  40.68514  -73.95976   89.0             1.0
# 4             61  40.79851  -73.94399   80.0            10.0
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9           0.210000                               6
# 1                 45           0.380000                               2
# 2                  0           1.373221                               1
# 3                270           4.640000                               1
# 4                  9           0.100000                               1
#
#    availability_365  price_log  ...  NEW_annual_income  \
# 0               365   5.010635  ...            54385.0
# 1               355   5.420535  ...            79875.0
# 2               365   5.017280  ...            54750.0
# 3               194   4.499810  ...            17266.0
# 4                 0   4.394449  ...                0.0
#
#    NEW_average_stay_duration  NEW_house_occupancy_rate  NEW_minimum_income  \
# 0                  42.857143                         0               149.0
# 1                 118.421053                        10               225.0
# 2                   0.000000                         0               450.0
# 3                  58.189655                       171                89.0
# 4                  90.000000                       365               800.0
#
#    neighbourhood_group_1  neighbourhood_group_2  neighbourhood_group_3  \
# 0                   True                  False                  False
# 1                  False                   True                  False
# 2                  False                   True                  False
# 3                   True                  False                  False
# 4                  False                   True                  False
#
#    neighbourhood_group_4  room_type_1  room_type_2
# 0                  False         True        False
# 1                  False        False        False
# 2                  False         True        False
# 3                  False        False        False
# 4                  False        False        False
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Standardization Process

# %%
num_cols = [col for col in num_cols if col not in ['price']]

# %%
num_cols
# Out:
# ['neighbourhood',
#  'latitude',
#  'longitude',
#  'minimum_nights',
#  'number_of_reviews',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'price_log',
#  'NEW_total_cost',
#  'NEW_estimated_listed_months',
#  'NEW_availability_ratio',
#  'NEW_daily_average_reviews',
#  'NEW_annual_income',
#  'NEW_average_stay_duration',
#  'NEW_house_occupancy_rate',
#  'NEW_minimum_income']

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

# %%
### Can u use different Scaling/standardization method for the model if can then
# Which technique and why ?

# %%
dff[num_cols] = scaler.fit_transform(dff[num_cols])

# %%
dff.head()
# Out:
#    neighbourhood  latitude  longitude  price  minimum_nights  \
# 0       0.110236 -1.035130  -0.356662  149.0           -0.50
# 1       0.259843  0.418407  -0.600278  225.0           -0.50
# 2       0.000000  1.177155   0.294476  150.0            0.00
# 3      -0.417323 -0.519482  -0.087189   89.0           -0.50
# 4      -0.259843  1.033212   0.249813   80.0            1.75
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0           0.173913          -0.776923                             5.0
# 1           1.739130          -0.646154                             1.0
# 2          -0.217391           0.117863                             0.0
# 3          11.521739           2.630769                             0.0
# 4           0.173913          -0.861538                             0.0
#
#    availability_365  price_log  ...  NEW_annual_income  \
# 0          1.409692   0.366389  ...           2.226311
# 1          1.365639   0.810971  ...           3.359200
# 2          1.409692   0.373596  ...           2.242533
# 3          0.656388  -0.187659  ...           0.576578
# 4         -0.198238  -0.301934  ...          -0.190800
#
#    NEW_average_stay_duration  NEW_house_occupancy_rate  NEW_minimum_income  \
# 0                   0.819125                 -1.409692           -0.251877
# 1                   3.017828                 -1.365639           -0.125104
# 2                  -0.427901                 -1.409692            0.250209
# 3                   1.265259                 -0.656388           -0.351960
# 4                   2.190853                  0.198238            0.834028
#
#    neighbourhood_group_1  neighbourhood_group_2  neighbourhood_group_3  \
# 0                   True                  False                  False
# 1                  False                   True                  False
# 2                  False                   True                  False
# 3                   True                  False                  False
# 4                  False                   True                  False
#
#    neighbourhood_group_4  room_type_1  room_type_2
# 0                  False         True        False
# 1                  False        False        False
# 2                  False         True        False
# 3                  False        False        False
# 4                  False        False        False
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Creating Model

# %%
y = dff['price']

# %%
x = dff.drop(['price', 'neighbourhood', 'price_log'], axis = 1)

# %%
x.head()
# Out:
#    latitude  longitude  minimum_nights  number_of_reviews  reviews_per_month  \
# 0 -1.035130  -0.356662           -0.50           0.173913          -0.776923
# 1  0.418407  -0.600278           -0.50           1.739130          -0.646154
# 2  1.177155   0.294476            0.00          -0.217391           0.117863
# 3 -0.519482  -0.087189           -0.50          11.521739           2.630769
# 4  1.033212   0.249813            1.75           0.173913          -0.861538
#
#    calculated_host_listings_count  availability_365  NEW_total_cost  \
# 0                             5.0          1.409692       -0.251877
# 1                             1.0          1.365639       -0.125104
# 2                             0.0          1.409692        0.250209
# 3                             0.0          0.656388       -0.351960
# 4                             0.0         -0.198238        0.834028
#
#    NEW_estimated_listed_months  NEW_availability_ratio  ...  \
# 0                     0.819125                1.409692  ...
# 1                     3.017828                1.365639  ...
# 2                    -0.427901                1.409692  ...
# 3                     1.265259                0.656388  ...
# 4                     2.190853               -0.198238  ...
#
#    NEW_annual_income  NEW_average_stay_duration  NEW_house_occupancy_rate  \
# 0           2.226311                   0.819125                 -1.409692
# 1           3.359200                   3.017828                 -1.365639
# 2           2.242533                  -0.427901                 -1.409692
# 3           0.576578                   1.265259                 -0.656388
# 4          -0.190800                   2.190853                  0.198238
#
#    NEW_minimum_income  neighbourhood_group_1  neighbourhood_group_2  \
# 0           -0.251877                   True                  False
# 1           -0.125104                  False                   True
# 2            0.250209                  False                   True
# 3           -0.351960                   True                  False
# 4            0.834028                  False                   True
#
#    neighbourhood_group_3  neighbourhood_group_4  room_type_1  room_type_2
# 0                  False                  False         True        False
# 1                  False                  False        False        False
# 2                  False                  False         True        False
# 3                  False                  False        False        False
# 4                  False                  False        False        False
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Splitting the data

# %%
x_train , x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics

# %%
models = [('LR', LinearRegression()),
          ("Ridge", Ridge()),
          ("Lasso", Lasso()),
         ]

rmse_scores = []
r2_scores = []
mae_scores = []
mse_scores = []

for name , regressor in models:
    
    regressor.fit(x_train, y_train)
    
    # making predictions
    y_pred = regressor.predict(x_test)
    
    # calculate RMSE 
  
    
    # calculate R^2 score 
  
    # calculate MAE
  
    # Calculate MSE 
  
    
    print(f"RMSE : {round(rmse, 4)} ({name})")
    print(f"R^2 Score: {round(r2, 4)} ({name})")
    print(f"MAE: {round(mae, 4)} ({name})")
    print(f"MSE: {round(mse, 4)} ({name})")
# Out:
# RMSE : 71.532 (LR)
# R^2 Score: 0.6523 (LR)
# MAE: 42.1631 (LR)
# MSE: 5051.3072 (LR)
# RMSE : 71.532 (Ridge)
# R^2 Score: 0.6523 (Ridge)
# MAE: 42.1613 (Ridge)
# MSE: 5051.308 (Ridge)
# RMSE : 72.0145 (Lasso)
# R^2 Score: 0.6441 (Lasso)
# MAE: 42.0876 (Lasso)
# MSE: 5170.9921 (Lasso)
# RMSE : 44.5905 (KNN)
# R^2 Score: 0.8878 (KNN)
# MAE: 22.1905 (KNN)
# MSE: 1629.3085 (KNN)
# RMSE : 13.0293 (DT)
# R^2 Score: 0.9931 (DT)
# MAE: 1.1998 (DT)
# MSE: 99.9603 (DT)
# RMSE : 9.9265 (RF)
# R^2 Score: 0.9969 (RF)
# MAE: 0.9466 (RF)
# MSE: 44.7619 (RF)
# RMSE : 20.7389 (GBM)
# R^2 Score: 0.9711 (GBM)
# MAE: 11.1014 (GBM)
# MSE: 420.3655 (GBM)
# RMSE : 8.4544 (XGBoost)
# R^2 Score: 0.9956 (XGBoost)
# MAE: 2.8961 (XGBoost)
# MSE: 63.4224 (XGBoost)
# RMSE : 5.6762 (CatBoost)
# R^2 Score: 0.9986 (CatBoost)
# MAE: 2.1332 (CatBoost)
# MSE: 20.4996 (CatBoost)

# %%
# Plot RMSE scores 
plt.figure(figsize = (10,10))
plt.bar([name for name, _ in models], rmse_scores)
plt.xlabel("Model")
plt.ylabel("RMSE")
plt.title("Model Performance (RMSE)")
plt.show()

# %% [markdown]
# ## Hyperparameter Optimization

# %%
models = [('LR', LinearRegression()),
          ("Ridge", Ridge()),
          ("Lasso", Lasso()),
         ]

rmse_scores = []
r2_scores = []
mae_scores = []
mse_scores = []

# Define the hyperparameters for each model
param_grids = {
    'LR': {},
    'Ridge': {'alpha': [0.1, 1.0]},
    'Lasso': {'alpha': [0.1, 1.0]},
    
}

# Train and evaluate the models with hyperparameter tuning
# Out:
# Hyperparameter Tuning for LR:
# RMSE: 71.0725 (LR)
# R^2 Score: 0.6523 (LR)
# MAE: 42.1631 (LR)
# MSE: 5051.3072 (LR)
# Hyperparameter Tuning for Ridge:
# Best parameters : {'alpha': 0.1}
# RMSE: 71.0725 (Ridge)
# R^2 Score: 0.6523 (Ridge)
# MAE: 42.1629 (Ridge)
# MSE: 5051.3071 (Ridge)
# Hyperparameter Tuning for Lasso:
# Best parameters : {'alpha': 0.1}
# RMSE: 71.1074 (Lasso)
# R^2 Score: 0.6519 (Lasso)
# MAE: 42.0701 (Lasso)
# MSE: 5056.2644 (Lasso)
# Hyperparameter Tuning for KNN:
# Best parameters : {'n_neighbors': 3}
# RMSE: 40.3448 (KNN)
# R^2 Score: 0.888 (KNN)
# MAE: 22.4463 (KNN)
# MSE: 1627.7 (KNN)
# Hyperparameter Tuning for DT:
# Best parameters : {'max_depth': None, 'min_samples_leaf': 2}
# RMSE: 10.3139 (DT)
# R^2 Score: 0.9927 (DT)
# MAE: 1.3108 (DT)
# MSE: 106.3771 (DT)
# Hyperparameter Tuning for RF:
# Best parameters : {'max_depth': None, 'n_estimators': 50}
# RMSE: 6.3249 (RF)
# R^2 Score: 0.9972 (RF)
# MAE: 0.9646 (RF)
# MSE: 40.0041 (RF)
# Hyperparameter Tuning for GBM:
# Best parameters : {'learning_rate': 0.1, 'n_estimators': 50}
# RMSE: 35.774 (GBM)
# R^2 Score: 0.9119 (GBM)
# MAE: 18.2337 (GBM)
# MSE: 1279.7815 (GBM)
# Hyperparameter Tuning for XGBoost:
# Best parameters : {'learning_rate': 0.1, 'n_estimators': 50}
# RMSE: 9.8315 (XGBoost)
# R^2 Score: 0.9933 (XGBoost)
# MAE: 4.8354 (XGBoost)
# MSE: 96.6577 (XGBoost)
# Hyperparameter Tuning for CatBoost:
# Best parameters : {'depth': 6, 'iterations': 50, 'learning_rate': 0.1}
# RMSE: 23.8656 (CatBoost)
# R^2 Score: 0.9608 (CatBoost)
# MAE: 14.0692 (CatBoost)
# MSE: 569.5685 (CatBoost)

# %% [markdown]
# ## Final Model predictions

# %%
# check your best model

# %%
final_model = best_model

# prediction on the test data 
y_final_pred = final_model.predict(x_test)
final_y_pred = y_final_pred
final_y_test = y_test

# %%
results = pd.DataFrame({'Predicted_Price' : final_y_pred, 'True_Price': final_y_test
                       })

results['Difference'] = results['True_Price'] - results['Predicted_Price']

results
# Out:
#        Predicted_Price  True_Price  Difference
# 879         109.272762        89.0  -20.272762
# 44383        33.418951        30.0   -3.418951
# 15394       111.728686       120.0    8.271314
# 43230       465.514573       470.0    4.485427
# 16332       175.551848       199.0   23.448152
# ...                ...         ...         ...
# 20477       201.987508       215.0   13.012492
# 44969        95.237065       100.0    4.762935
# 36577        69.934874        70.0    0.065126
# 11477       411.356663       500.0   88.643337
# 1023        118.717153       125.0    6.282847
#
# [9779 rows x 3 columns]

# %%
results.tail()
# Out:
#        Predicted_Price  True_Price  Difference
# 20477       201.987508       215.0   13.012492
# 44969        95.237065       100.0    4.762935
# 36577        69.934874        70.0    0.065126
# 11477       411.356663       500.0   88.643337
# 1023        118.717153       125.0    6.282847
